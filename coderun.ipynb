# %% [markdown]
# <a href="https://colab.research.google.com/github/dorisagusioboechianu-blip/CSC500-1_Module-1-Critical-Thinking-Assignment/blob/main/Untitled18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Part 1:
# Write a Python program to find the addition and subtraction of two numbers.
#
# Ask the user to input two numbers (num1 and num2). Given those two numbers, add them together to find the output. Also, subtract the two numbers to find the output.

# %%
# calc.py - interactive
num1 = float(input("Enter the first number: "))
num2 = float(input("Enter the second number: "))

sum_result = num1 + num2
sub_result = num1 - num2

print("The sum of", num1, "and", num2, "is:", sum_result)
print("The difference between", num1, "and", num2, "is:", sub_result)

# %% [markdown]
# Part 2: Write a Python program to find the multiplication and division of two numbers.
#
# Ask the user to input two numbers (num1 and num2). Given those two numbers, multiply them together to find the output. Also, divide num1/num2 to find the output.

# %%
# Program to find multiplication and division of two numbers

# Ask the user to input two numbers
num1 = float(input("Enter the first number: "))
num2 = float(input("Enter the second number: "))

# Perform multiplication
mul_result = num1 * num2

# Perform division (handle divide-by-zero safely)
if num2 != 0:
    div_result = num1 / num2
else:
    div_result = "Undefined (cannot divide by zero)"

# Display the results
print("The product of", num1, "and", num2, "is:", mul_result)
print("The division of", num1, "by", num2, "is:", div_result)
# Out:
# Enter the first number: 68
# Enter the second number: 0.89
# The product of 68.0 and 0.89 is: 60.52
# The division of 68.0 by 0.89 is: 76.40449438202248
